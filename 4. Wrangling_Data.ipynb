# %% [markdown]
# [Home](https://pandas.pydata.org/pandas-docs/stable/index.html)
# [What's New](https://pandas.pydata.org/pandas-docs/stable/whatsnew/v1.0.1.html)
# [Getting Started](https://pandas.pydata.org/pandas-docs/stable/getting_started/index.html)
# [User Guide](https://pandas.pydata.org/pandas-docs/stable/user_guide/index.html)
# [API Reference](https://pandas.pydata.org/pandas-docs/stable/reference/index.html)
# [Development](https://pandas.pydata.org/pandas-docs/stable/development/index.html)
# [Release Notes](https://pandas.pydata.org/pandas-docs/stable/whatsnew/index.html)
# ***
# <img src="https://pandas.pydata.org/pandas-docs/stable/_static/pandas.svg" align="left" alt="dataframe image" width = "400">
# ***

# %%
#standard import The community agreed alias for pandas is pd, so loading pandas as pd is assumed standard practice for all of the pandas documentation.

import pandas as pd

# %% [markdown]
# If you have downloaded a conda distribution then you can ensure you have pandas and update it appropriately (conda install/update pandas) and or utilize (pip install pandas)

# %% [markdown]
# When working with tabular data, such as data stored in spreadsheets or databases, Pandas is the right tool for you when working in Jupyter Notebook or Lab. Pandas helps you to explore, clean, visualize, analyze and process your data. In Pandas, a data table is called a [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html#pandas.DataFrame).
#
# <!--![dataframe](images/dataframe.png) -->
# <img src="https://pandas.pydata.org/pandas-docs/stable/_images/01_table_dataframe.svg" align="left" alt="dataframe image" width = "400">

# %%
# %%file data/data.csv
# Date,Open,High,Low,Close,Volume,Adj Close
# 2012-06-01,569.16,590.00,548.50,584.00,14077000,581.50
# 2012-05-01,584.90,596.76,522.18,577.73,18827900,575.26
# 2012-04-02,601.83,644.00,555.00,583.98,28759100,581.48
# 2012-03-01,548.17,621.45,516.22,599.55,26486000,596.99
# 2012-02-01,458.41,547.61,453.98,542.44,22001000,540.12
# 2012-01-03,409.40,458.24,409.00,456.48,12949100,454.53
# Out:
# Overwriting data/data.csv

# %%
# !ls data
# Out:
# AI_Tools.csv             kernels.csv
# data.csv                 rdu-weather-history.json

# %% [markdown]
# Read this as into a DataFrame:

# %%
df = pd.read_csv('data/data.csv')

# %%
df
# Out:
#          Date    Open    High     Low   Close    Volume  Adj Close
# 0  2012-06-01  569.16  590.00  548.50  584.00  14077000     581.50
# 1  2012-05-01  584.90  596.76  522.18  577.73  18827900     575.26
# 2  2012-04-02  601.83  644.00  555.00  583.98  28759100     581.48
# 3  2012-03-01  548.17  621.45  516.22  599.55  26486000     596.99
# 4  2012-02-01  458.41  547.61  453.98  542.44  22001000     540.12
# 5  2012-01-03  409.40  458.24  409.00  456.48  12949100     454.53

# %% [markdown]
# Each column in a DataFrame is a Series!

# %%
#to call just one column and put it into a series
df['Volume']
# Out:
# 0    14077000
# 1    18827900
# 2    28759100
# 3    26486000
# 4    22001000
# 5    12949100
# Name: Volume, dtype: int64

# %%
#to call a row of data use .loc[index]
df.loc[3]
# Out:
# Date         2012-03-01
# Open             548.17
# High             621.45
# Low              516.22
# Close            599.55
# Volume         26486000
# Adj Close        596.99
# Name: 3, dtype: object

# %%
#to call just one column and statistically describe
df['Volume'].describe()
# Out:
# count    6.000000e+00
# mean     2.051668e+07
# std      6.439925e+06
# min      1.294910e+07
# 25%      1.526472e+07
# 50%      2.041445e+07
# 75%      2.536475e+07
# max      2.875910e+07
# Name: Volume, dtype: float64

# %% [markdown]
# Pandas supports the integration with many file formats or data sources out of the box (csv, excel, sql, json, parquet,html, hdf5). Importing data from each of these data sources is provided by function with the prefix read_*. Similarly, the to_* methods are used to store data. see supported list: https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html
#
# <img src="https://pandas.pydata.org/pandas-docs/stable/_images/02_io_readwrite.svg" alt="dataframe image" width = "600">

# %%
df2 = pd.read_csv('data/AI_Tools.csv')

# %%
df2.head()
# Out:
#                 Tool/Capability  \
# 0               Adobe Photoshop
# 1                 Amazon Backup
# 2             Amazon Comprehend
# 3               Amazon DynamoDB
# 4  Amazon Elastic Block Storage
#
#                                          Description  Capability Type
# 0       Adobe Photoshop is a raster graphics editor.  Graphic editing
# 1  Fully managed backup service that makes it eas...        AWS Tools
# 2  Amazon Comprehend is a natural language proces...        AWS Tools
# 3  Amazon DynamoDB is a fully managed proprietary...        AWS Tools
# 4  Persistent, durable, low-latency block-level s...        AWS Tools

# %%
list(df2.columns)
# Out:
# ['Tool/Capability', 'Description', 'Capability Type']

# %%
df4 = df2[['Tool/Capability', 'Capability Type' ]]

# %%
df4.groupby(['Capability Type']).count()
# Out:
#                                  Tool/Capability
# Capability Type
# AI/ML Tools                                   58
# AWS Tools                                     33
# Automation/Infrastructure Tools               34
# Azure Tools                                   21
# Collaboration Tools                            3
# Data Ingestion/Manipulation                   23
# Data Visualization                             9
# Database                                      14
# DevSecOps Tools                               30
# Docker Tools                                   5
# Graphic editing                                1
# Log Ingestion/Manipulation                     3
# OS                                             8
# OS Tools                                       1
# Repository Tools/Library                      19
# Requirements                                   1
# Visualization Tools                            3

# %%
#You would be hard pressed to find any place better to get federal data and integrate into your project. Data.gov
import webbrowser
datagov = 'https://www.data.gov/'
webbrowser.open(datagov)
# Out:
# True

# %%
#https://catalog.data.gov/dataset/local-weather-archive Town of Cary, North Carolina
# !ls data
# Out:
# AI_Tools.csv             kernels.csv
# data.csv                 rdu-weather-history.json

# %%
weatherdf = pd.read_json('data/rdu-weather-history.json')

# %%
list(weatherdf.columns)
# Out:
# ['fogground',
#  'snowfall',
#  'dust',
#  'snowdepth',
#  'mist',
#  'drizzle',
#  'hail',
#  'fastest2minwindspeed',
#  'thunder',
#  'glaze',
#  'snow',
#  'ice',
#  'fog',
#  'temperaturemin',
#  'fastest5secwindspeed',
#  'freezingfog',
#  'temperaturemax',
#  'blowingsnow',
#  'freezingrain',
#  'rain',
#  'highwind',
#  'date',
#  'precipitation',
#  'fogheavy',
#  'smokehaze',
#  'avgwindspeed',
#  'fastest2minwinddir',
#  'fastest5secwinddir']

# %%
weatherdf.head()
# Out:
#   fogground  snowfall dust  snowdepth mist drizzle hail  fastest2minwindspeed  \
# 0        No       0.0   No        0.0  Yes      No   No                 17.90
# 1        No       0.0   No        0.0   No      No   No                 23.04
# 2        No       0.0   No        0.0   No      No   No                 23.94
# 3        No       0.0   No        0.0  Yes     Yes   No                  8.05
# 4        No       0.0   No        0.0   No      No   No                 17.90
#
#   thunder glaze  ... freezingrain rain highwind       date  precipitation  \
# 0      No    No  ...           No  Yes       No 2007-01-06           0.13
# 1      No    No  ...           No  Yes       No 2007-01-09           0.00
# 2      No    No  ...           No   No       No 2007-01-15           0.00
# 3      No    No  ...           No  Yes       No 2007-01-22           0.08
# 4      No    No  ...           No   No       No 2007-01-30           0.00
#
#   fogheavy  smokehaze avgwindspeed fastest2minwinddir fastest5secwinddir
# 0       No         No         8.05              230.0              230.0
# 1       No         No         7.61              280.0              270.0
# 2       No         No        13.20              230.0              230.0
# 3       No         No         2.01              230.0               10.0
# 4       No         No         5.82              220.0              220.0
#
# [5 rows x 28 columns]

# %%
weatherdf
# Out:
#      fogground  snowfall dust  snowdepth mist drizzle hail  \
# 0           No       0.0   No        0.0  Yes      No   No
# 1           No       0.0   No        0.0   No      No   No
# 2           No       0.0   No        0.0   No      No   No
# 3           No       0.0   No        0.0  Yes     Yes   No
# 4           No       0.0   No        0.0   No      No   No
# ...        ...       ...  ...        ...  ...     ...  ...
# 4839        No       0.0   No        0.0   No      No   No
# 4840        No       0.0   No        0.0   No      No   No
# 4841        No       0.0   No        0.0   No      No   No
# 4842        No       0.0   No        0.0   No      No   No
# 4843        No       0.0   No        0.0   No      No   No
#
#       fastest2minwindspeed thunder glaze  ... freezingrain rain highwind  \
# 0                    17.90      No    No  ...           No  Yes       No
# 1                    23.04      No    No  ...           No  Yes       No
# 2                    23.94      No    No  ...           No   No       No
# 3                     8.05      No    No  ...           No  Yes       No
# 4                    17.90      No    No  ...           No   No       No
# ...                    ...     ...   ...  ...          ...  ...      ...
# 4839                 23.94      No    No  ...           No   No       No
# 4840                 17.00     Yes    No  ...           No   No       No
# 4841                 14.99      No    No  ...           No   No       No
# 4842                 17.00      No    No  ...           No   No       No
# 4843                 18.12      No    No  ...           No   No       No
#
#            date  precipitation fogheavy  smokehaze avgwindspeed  \
# 0    2007-01-06           0.13       No         No         8.05
# 1    2007-01-09           0.00       No         No         7.61
# 2    2007-01-15           0.00       No         No        13.20
# 3    2007-01-22           0.08       No         No         2.01
# 4    2007-01-30           0.00       No         No         5.82
# ...         ...            ...      ...        ...          ...
# 4839 2020-03-09           0.00       No         No        11.41
# 4840 2020-03-25           0.86       No         No         7.16
# 4841 2020-03-26           0.00       No         No         5.14
# 4842 2020-03-27           0.00       No         No         8.50
# 4843 2020-03-30           0.00       No         No         7.16
#
#      fastest2minwinddir fastest5secwinddir
# 0                 230.0              230.0
# 1                 280.0              270.0
# 2                 230.0              230.0
# 3                 230.0               10.0
# 4                 220.0              220.0
# ...                 ...                ...
# 4839              230.0              230.0
# 4840              280.0              280.0
# 4841              230.0              230.0
# 4842              240.0              230.0
# 4843              280.0              280.0
#
# [4844 rows x 28 columns]

# %%
#You can also use boolean to ask questions
snowed = weatherdf['snowfall'] > 0

# %%
snowed
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4839    False
# 4840    False
# 4841    False
# 4842    False
# 4843    False
# Name: snowfall, Length: 4844, dtype: bool

# %%
weatherdf.snowfall.value_counts()
# Out:
# 0.00    4793
# 0.20       7
# 0.39       6
# 0.31       4
# 0.71       3
# 0.51       3
# 0.98       3
# 1.42       3
# 0.12       3
# 1.89       2
# 0.59       2
# 1.18       2
# 3.19       2
# 0.91       2
# 0.79       1
# 6.69       1
# 7.01       1
# 3.58       1
# 3.31       1
# 2.52       1
# 3.50       1
# 5.91       1
# Name: snowfall, dtype: int64

# %%
weatherdf.precipitation.value_counts()
# Out:
# 0.00    3283
# 0.01     131
# 0.02      79
# 0.03      65
# 0.04      53
#         ...
# 1.20       1
# 6.45       1
# 2.45       1
# 1.36       1
# 0.95       1
# Name: precipitation, Length: 189, dtype: int64

# %%
import numpy as np
from pandas import Series, DataFrame

# %%
#Quicklearn DataFrames

#Let's get some data to play with. How about the Jupyter Kernels github
import webbrowser
website = 'https://github.com/jupyter/jupyter/wiki/Jupyter-kernels'
webbrowser.open(website)
# Out:
# True

# %%
#Copy and read to get data
kernels = pd.read_clipboard()

# %%
kernels
# Out:
#                                       Name Jupyter/IPython Version  \
# 0                              Agda kernel                     NaN
# 1                    Dyalog Jupyter Kernel                     NaN
# 2                          Coarray-Fortran             Jupyter 4.0
# 3                   Ansible Jupyter Kernel      Jupyter 5.6.0.dev0
# 4                               sparkmagic           Jupyter >=4.0
# ..                                     ...                     ...
# 133                                 Bacatá                 Jupyter
# 134                           nelu-kernelu                 Jupyter
# 135                              IPolyglot                 Jupyter
# 136                           Emu86 Kernel                 Jupyter
# 137  Common Workflow Language (CWL) Kernel                     NaN
#
#                                    Language(s) Version  \
# 0                                                2.6.0
# 1                                         APL (Dyalog)
# 2                                    Fortran 2008/2015
# 3                                          Ansible 2.x
# 4    Pyspark (Python 2 & 3), Spark (Scala), SparkR (R)
# ..                                                 ...
# 133                                      Java & Rascal
# 134                                          NodeJs 12
# 135              JavaScript, Ruby, Python, R, and more
# 136                            Intel Assembly Language
# 137                                               v1.0
#
#                           3rd party dependencies  \
# 0                                            NaN
# 1                                 Dyalog >= 15.0
# 2    GFortran >= 7.1, OpenCoarrays, MPICH >= 3.2
# 3                                            NaN
# 4                                           Livy
# ..                                           ...
# 133                              ZeroMQ & Rascal
# 134                                 NodeJs 12.3+
# 135                                      GraalVM
# 136                                          NaN
# 137                                          NaN
#
#                                      Example Notebooks  \
# 0    https://mybinder.org/v2/gh/lclem/agda-kernel/m...
# 1                                            Notebooks
# 2                                    Demo, Binder demo
# 3                                          Hello World
# 4                             Notebooks, Docker Images
# ..                                                 ...
# 133                                            Example
# 134                                           Examples
# 135                          Example Polyglot Notebook
# 136   Introduction to Intel Assembly Language Tutorial
# 137                                 examples directory
#
#                                                  Notes
# 0                                                  NaN
# 1                Can also be run on TryAPL's Learn tab
# 2                                         Docker image
# 3                                                  NaN
# 4    This kernels are implemented via the magics ma...
# ..                                                 ...
# 133  A Jupyter kernel generator for domain-specific...
# 134  An advanced NodeJs Jupyter kernel supporting c...
# 135                                         Dockerfile
# 136                                                NaN
# 137                                  under development
#
# [138 rows x 6 columns]

# %%
#write to file to save your dataframe as a csv
kernels.to_csv(r'data/kernels.csv')

# %%
# !ls data
# Out:
# AI_Tools.csv             kernels.csv
# data.csv                 rdu-weather-history.json

# %%
# We can view the column names with .columns
kernels.columns
# Out:
# Index(['Name', 'Jupyter/IPython Version', 'Language(s) Version',
#        '3rd party dependencies', 'Example Notebooks', 'Notes'],
#       dtype='object')

# %%
#View specific data columns
DataFrame(kernels,columns=['Name','Language(s) Version','Notes'])
# Out:
#                                       Name  \
# 0                              Agda kernel
# 1                    Dyalog Jupyter Kernel
# 2                          Coarray-Fortran
# 3                   Ansible Jupyter Kernel
# 4                               sparkmagic
# ..                                     ...
# 133                                 Bacatá
# 134                           nelu-kernelu
# 135                              IPolyglot
# 136                           Emu86 Kernel
# 137  Common Workflow Language (CWL) Kernel
#
#                                    Language(s) Version  \
# 0                                                2.6.0
# 1                                         APL (Dyalog)
# 2                                    Fortran 2008/2015
# 3                                          Ansible 2.x
# 4    Pyspark (Python 2 & 3), Spark (Scala), SparkR (R)
# ..                                                 ...
# 133                                      Java & Rascal
# 134                                          NodeJs 12
# 135              JavaScript, Ruby, Python, R, and more
# 136                            Intel Assembly Language
# 137                                               v1.0
#
#                                                  Notes
# 0                                                  NaN
# 1                Can also be run on TryAPL's Learn tab
# 2                                         Docker image
# 3                                                  NaN
# 4    This kernels are implemented via the magics ma...
# ..                                                 ...
# 133  A Jupyter kernel generator for domain-specific...
# 134  An advanced NodeJs Jupyter kernel supporting c...
# 135                                         Dockerfile
# 136                                                NaN
# 137                                  under development
#
# [138 rows x 3 columns]

# %%
#We can view/retrieive individual columns
kernels['Name']
# Out:
# 0                                Agda kernel
# 1                      Dyalog Jupyter Kernel
# 2                            Coarray-Fortran
# 3                     Ansible Jupyter Kernel
# 4                                 sparkmagic
#                        ...
# 133                                   Bacatá
# 134                             nelu-kernelu
# 135                                IPolyglot
# 136                             Emu86 Kernel
# 137    Common Workflow Language (CWL) Kernel
# Name: Name, Length: 138, dtype: object

# %%
#We can retrieve  a specific row through indexing
kernels.loc[10]
# Out:
# Name                                                                   tslab
# Jupyter/IPython Version                                                  NaN
# Language(s) Version                      Typescript 3.7.2, JavaScript ESNext
# 3rd party dependencies                                               Node.js
# Example Notebooks                                          Example notebooks
# Notes                      Jupyter kernel for JavaScript and TypeScript -...
# Name: 10, dtype: object

# %%
#Can also view an index range
kernels[20:30]
# Out:
#                                 Name         Jupyter/IPython Version  \
# 20                               lgo        Jupyter >= 4, JupyterLab
# 21                          iGalileo        Jupyter >= 4, JupyterLab
# 22                         gopherlab         Jupyter 4.1, JupyterLab
# 23                       Gophernotes  Jupyter 4, JupyterLab, nteract
# 24                               IGo                             NaN
# 25                            IScala                             NaN
# 26  almond (old name: Jupyter-scala)                    IPython>=3.0
# 27                           IErlang                     IPython 2.3
# 28                            ITorch       IPython >= 2.2 and <= 5.x
# 29                           IElixir                  Jupyter >= 4.0
#
#    Language(s) Version     3rd party dependencies  \
# 20           Go >= 1.8               ZeroMQ (4.x)
# 21    Galileo >= 0.1.3                        NaN
# 22           Go >= 1.6               ZeroMQ (4.x)
# 23           Go >= 1.9               ZeroMQ 4.x.x
# 24           Go >= 1.4                        NaN
# 25               Scala                        NaN
# 26         Scala>=2.10                        NaN
# 27              Erlang                      rebar
# 28    Torch 7 (LuaJIT)                        NaN
# 29       Elixir >= 1.5  Erlang OTP >= 19.3, Rebar
#
#                                     Example Notebooks  \
# 20                                            Example
# 21                                                NaN
# 22                                           examples
# 23                                           examples
# 24                                                NaN
# 25                                                NaN
# 26                                           examples
# 27                                                NaN
# 28                                                NaN
# 29  example, Boyle package manager examples, Boyle...
#
#                                                Notes
# 20                                      Docker image
# 21                                      Docker image
# 22                       Deprecated, use gophernotes
# 23                                      docker image
# 24                     Unmaintained, use gophernotes
# 25                                               NaN
# 26                                              Docs
# 27                                               NaN
# 28                                               NaN
# 29  IElixir Docker image, IElixir Notebook in Docker

# %%
#Another way to select and view multiple columns
kernels[['Name','Language(s) Version']]
# Out:
#                                       Name  \
# 0                              Agda kernel
# 1                    Dyalog Jupyter Kernel
# 2                          Coarray-Fortran
# 3                   Ansible Jupyter Kernel
# 4                               sparkmagic
# ..                                     ...
# 133                                 Bacatá
# 134                           nelu-kernelu
# 135                              IPolyglot
# 136                           Emu86 Kernel
# 137  Common Workflow Language (CWL) Kernel
#
#                                    Language(s) Version
# 0                                                2.6.0
# 1                                         APL (Dyalog)
# 2                                    Fortran 2008/2015
# 3                                          Ansible 2.x
# 4    Pyspark (Python 2 & 3), Spark (Scala), SparkR (R)
# ..                                                 ...
# 133                                      Java & Rascal
# 134                                          NodeJs 12
# 135              JavaScript, Ruby, Python, R, and more
# 136                            Intel Assembly Language
# 137                                               v1.0
#
# [138 rows x 2 columns]

# %%
#You can also use boolean to ask questions
kernels[kernels['Language(s) Version']=='NodeJs 12']
# Out:
#              Name Jupyter/IPython Version Language(s) Version  \
# 134  nelu-kernelu                 Jupyter           NodeJs 12
#
#     3rd party dependencies Example Notebooks  \
# 134           NodeJs 12.3+          Examples
#
#                                                  Notes
# 134  An advanced NodeJs Jupyter kernel supporting c...
