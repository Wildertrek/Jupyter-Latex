# %%
import pandas as pd

# %%
#set max columns
pd.set_option('display.max_columns', None)

# %%
# set max rows
pd.set_option('display.max_rows', None)

# %%
Tools = pd.read_csv('data/AI_Tools.csv')

# %%
Tools
# Out:
#                                        Tool/Capability  \
# 0                                      Adobe Photoshop
# 1                                        Amazon Backup
# 2                                    Amazon Comprehend
# 3                                      Amazon DynamoDB
# 4                         Amazon Elastic Block Storage
# 5                           Amazon Elastic File System
# 6                             Amazon Elastic Inference
# 7                                      Amazon Forecast
# 8                                  Amazon Ground Truth
# 9                                       Amazon Kinesis
# 10                                          Amazon Lex
# 11                      Amazon Mechanical Turk (Mturk)
# 12                                  Amazon Personalize
# 13                                        Amazon Polly
# 14                                  Amazon Rekognition
# 15                                           Amazon S3
# ...

# %%
list(Tools.columns)
# Out:
# ['Tool/Capability', 'Description', 'Capability Type']

# %%
Tools_List = Tools[['Tool/Capability', 'Capability Type' ]]

# %%
Tools_List
# Out:
#                                        Tool/Capability  \
# 0                                      Adobe Photoshop
# 1                                        Amazon Backup
# 2                                    Amazon Comprehend
# 3                                      Amazon DynamoDB
# 4                         Amazon Elastic Block Storage
# 5                           Amazon Elastic File System
# 6                             Amazon Elastic Inference
# 7                                      Amazon Forecast
# 8                                  Amazon Ground Truth
# 9                                       Amazon Kinesis
# 10                                          Amazon Lex
# 11                      Amazon Mechanical Turk (Mturk)
# 12                                  Amazon Personalize
# 13                                        Amazon Polly
# 14                                  Amazon Rekognition
# 15                                           Amazon S3
# ...

# %%
Tools_List.groupby(['Capability Type']).count()
# Out:
#                                  Tool/Capability
# Capability Type
# AI/ML Tools                                   58
# AWS Tools                                     33
# Automation/Infrastructure Tools               34
# Azure Tools                                   21
# Collaboration Tools                            3
# Data Ingestion/Manipulation                   23
# Data Visualization                             9
# Database                                      14
# DevSecOps Tools                               30
# Docker Tools                                   5
# Graphic editing                                1
# Log Ingestion/Manipulation                     3
# OS                                             8
# OS Tools                                       1
# Repository Tools/Library                      19
# Requirements                                   1
# Visualization Tools                            3
