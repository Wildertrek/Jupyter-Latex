# %%
sessionInfo()
# Out:
# R version 3.6.1 (2019-07-05)
# Platform: x86_64-apple-darwin13.4.0 (64-bit)
# Running under: macOS Catalina 10.15.6
#
# Matrix products: default
# BLAS/LAPACK: /Applications/anaconda3/lib/R/lib/libRblas.dylib
#
# locale:
# [1] en_US.UTF-8/en_US.UTF-8/en_US.UTF-8/C/en_US.UTF-8/en_US.UTF-8
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# loaded via a namespace (and not attached):
#  [1] compiler_3.6.1  IRdisplay_0.7.0 pbdZMQ_0.3-3    tools_3.6.1
#  [5] htmltools_0.3.6 base64enc_0.1-3 crayon_1.3.4    Rcpp_1.0.1
#  [9] uuid_0.1-2      IRkernel_0.8.15 jsonlite_1.6    digest_0.6.18
# [13] repr_0.19.2     evaluate_0.13

# %%
getRversion()
# Out:
# [1] ‘3.6.1’

# %%
installed.packages()
# Out:
#              Package      LibPath                               Version
# assertthat   assertthat   /Applications/anaconda3/lib/R/library 0.2.1
# base         base         /Applications/anaconda3/lib/R/library 3.6.1
# base64enc    base64enc    /Applications/anaconda3/lib/R/library 0.1-3
# BH           BH           /Applications/anaconda3/lib/R/library 1.72.0-3
# bindr        bindr        /Applications/anaconda3/lib/R/library 0.1.1
# clipr        clipr        /Applications/anaconda3/lib/R/library 0.7.0
# compiler     compiler     /Applications/anaconda3/lib/R/library 3.6.1
# crayon       crayon       /Applications/anaconda3/lib/R/library 1.3.4
# datasets     datasets     /Applications/anaconda3/lib/R/library 3.6.1
# DBI          DBI          /Applications/anaconda3/lib/R/library 1.1.0
# desc         desc         /Applications/anaconda3/lib/R/library 1.2.0
# digest       digest       /Applications/anaconda3/lib/R/library 0.6.18
# evaluate     evaluate     /Applications/anaconda3/lib/R/library 0.13
# generics     generics     /Applications/anaconda3/lib/R/library 0.0.2
# graphics     graphics     /Applications/anaconda3/lib/R/library 3.6.1
# grDevices    grDevices    /Applications/anaconda3/lib/R/library 3.6.1
# grid         grid         /Applications/anaconda3/lib/R/library 3.6.1
# gtable       gtable       /Applications/anaconda3/lib/R/library 0.3.0
# highr        highr        /Applications/anaconda3/lib/R/library 0.8
# htmltools    htmltools    /Applications/anaconda3/lib/R/library 0.3.6
# IRdisplay    IRdisplay    /Applications/anaconda3/lib/R/library 0.7.0
# IRkernel     IRkernel     /Applications/anaconda3/lib/R/library 0.8.15
# jsonlite     jsonlite     /Applications/anaconda3/lib/R/library 1.6
# labeling     labeling     /Applications/anaconda3/lib/R/library 0.3
# magrittr     magrittr     /Applications/anaconda3/lib/R/library 1.5
# methods      methods      /Applications/anaconda3/lib/R/library 3.6.1
# parallel     parallel     /Applications/anaconda3/lib/R/library 3.6.1
# pbdZMQ       pbdZMQ       /Applications/anaconda3/lib/R/library 0.3-3
# pkgconfig    pkgconfig    /Applications/anaconda3/lib/R/library 2.0.3
# plogr        plogr        /Applications/anaconda3/lib/R/library 0.2.0
# praise       praise       /Applications/anaconda3/lib/R/library 1.0.0
# prettyunits  prettyunits  /Applications/anaconda3/lib/R/library 1.1.1
# R6           R6           /Applications/anaconda3/lib/R/library 2.4.1
# RColorBrewer RColorBrewer /Applications/anaconda3/lib/R/library 1.1-2
# Rcpp         Rcpp         /Applications/anaconda3/lib/R/library 1.0.1
# rematch      rematch      /Applications/anaconda3/lib/R/library 1.0.1
# repr         repr         /Applications/anaconda3/lib/R/library 0.19.2
# rstudioapi   rstudioapi   /Applications/anaconda3/lib/R/library 0.11
# rvest        rvest        /Applications/anaconda3/lib/R/library 0.3.5
# selectr      selectr      /Applications/anaconda3/lib/R/library 0.4-2
# splines      splines      /Applications/anaconda3/lib/R/library 3.6.1
# stats        stats        /Applications/anaconda3/lib/R/library 3.6.1
# stats4       stats4       /Applications/anaconda3/lib/R/library 3.6.1
# tcltk        tcltk        /Applications/anaconda3/lib/R/library 3.6.1
# tinytex      tinytex      /Applications/anaconda3/lib/R/library 0.22
# tools        tools        /Applications/anaconda3/lib/R/library 3.6.1
# utils        utils        /Applications/anaconda3/lib/R/library 3.6.1
# uuid         uuid         /Applications/anaconda3/lib/R/library 0.1-2
# viridisLite  viridisLite  /Applications/anaconda3/lib/R/library 0.3.0
# whisker      whisker      /Applications/anaconda3/lib/R/library 0.4
# withr        withr        /Applications/anaconda3/lib/R/library 2.2.0
# xfun         xfun         /Applications/anaconda3/lib/R/library 0.13
#              Priority Depends
# assertthat   NA       NA
# base         base     NA
# base64enc    NA       R (>= 2.9.0)
# BH           NA       NA
# bindr        NA       NA
# clipr        NA       NA
# compiler     base     NA
# crayon       NA       NA
# datasets     base     NA
# DBI          NA       methods, R (>= 3.0.0)
# desc         NA       R (>= 3.1.0)
# digest       NA       R (>= 3.1.0)
# evaluate     NA       R (>= 3.0.2)
# generics     NA       R (>= 3.1)
# graphics     base     NA
# grDevices    base     NA
# grid         base     NA
# gtable       NA       R (>= 3.0)
# highr        NA       R (>= 3.2.3)
# htmltools    NA       R (>= 2.14.1)
# IRdisplay    NA       R (>= 3.0.1)
# IRkernel     NA       R (>= 3.2.0)
# jsonlite     NA       methods
# labeling     NA       NA
# magrittr     NA       NA
# methods      base     NA
# parallel     base     NA
# pbdZMQ       NA       R (>= 3.2.0)
# pkgconfig    NA       NA
# plogr        NA       NA
# praise       NA       NA
# prettyunits  NA       NA
# R6           NA       R (>= 3.0)
# RColorBrewer NA       R (>= 2.0.0)
# Rcpp         NA       R (>= 3.0.0)
# rematch      NA       NA
# repr         NA       R (>= 3.0.1)
# rstudioapi   NA       NA
# rvest        NA       R (>= 3.2), xml2
# selectr      NA       R (>= 3.0)
# splines      base     NA
# stats        base     NA
# stats4       base     NA
# tcltk        base     NA
# tinytex      NA       NA
# tools        base     NA
# utils        base     NA
# uuid         NA       R (>= 2.9.0)
# viridisLite  NA       R (>= 2.10)
# whisker      NA       NA
# withr        NA       R (>= 3.2.0)
# xfun         NA       NA
#              Imports
# assertthat   tools
# base         NA
# base64enc    NA
# BH           NA
# bindr        NA
# clipr        utils
# compiler     NA
# crayon       grDevices, methods, utils
# datasets     NA
# DBI          NA
# desc         assertthat, utils, R6, crayon, rprojroot
# digest       NA
# evaluate     methods
# generics     methods
# graphics     grDevices
# grDevices    NA
# grid         grDevices, utils
# gtable       grid
# highr        NA
# htmltools    utils, digest, Rcpp
# IRdisplay    methods, repr
# IRkernel     repr (>= 0.4.99),\nmethods,\nevaluate (>= 0.10),\nIRdisplay (>= 0.3.0.9999),\npbdZMQ (>= 0.2-1),\ncrayon,\njsonlite (>= 0.9.6),\nuuid,\ndigest
# jsonlite     NA
# labeling     NA
# magrittr     NA
# methods      utils, stats
# parallel     tools, compiler
# pbdZMQ       NA
# pkgconfig    utils
# plogr        NA
# praise       NA
# prettyunits  NA
# R6           NA
# RColorBrewer NA
# Rcpp         methods, utils
# rematch      NA
# repr         utils, grDevices, htmltools, jsonlite, base64enc
# rstudioapi   NA
# rvest        httr (>= 0.5), magrittr, selectr
# selectr      methods, stringr, R6
# splines      graphics, stats
# stats        utils, grDevices, graphics
# stats4       graphics, methods, stats
# tcltk        utils
# tinytex      xfun (>= 0.5)
# tools        NA
# utils        NA
# uuid         NA
# viridisLite  NA
# whisker      NA
# withr        graphics, grDevices, stats
# xfun         stats, tools
#              LinkingTo
# assertthat   NA
# base         NA
# base64enc    NA
# BH           NA
# bindr        NA
# clipr        NA
# compiler     NA
# crayon       NA
# datasets     NA
# DBI          NA
# desc         NA
# digest       NA
# evaluate     NA
# generics     NA
# graphics     NA
# grDevices    NA
# grid         NA
# gtable       NA
# highr        NA
# htmltools    Rcpp
# IRdisplay    NA
# IRkernel     NA
# jsonlite     NA
# labeling     NA
# magrittr     NA
# methods      NA
# parallel     NA
# pbdZMQ       NA
# pkgconfig    NA
# plogr        NA
# praise       NA
# prettyunits  NA
# R6           NA
# RColorBrewer NA
# Rcpp         NA
# rematch      NA
# repr         NA
# rstudioapi   NA
# rvest        NA
# selectr      NA
# splines      NA
# stats        NA
# stats4       NA
# tcltk        NA
# tinytex      NA
# tools        NA
# utils        NA
# uuid         NA
# viridisLite  NA
# whisker      NA
# withr        NA
# xfun         NA
#              Suggests
# assertthat   testthat, covr
# base         methods
# base64enc    NA
# BH           NA
# bindr        testthat
# clipr        covr, knitr, rmarkdown, rstudioapi (>= 0.5), testthat (>=\n2.0.0)
# compiler     NA
# crayon       mockery, rstudioapi, testthat, withr
# datasets     NA
# DBI          blob, covr, hms, knitr, magrittr, rmarkdown, rprojroot,\nRSQLite (>= 1.1-2), testthat, xml2
# desc         covr, testthat, whoami, withr
# digest       knitr, rmarkdown
# evaluate     testthat, lattice, ggplot2
# generics     covr, pkgload, testthat, tibble
# graphics     NA
# grDevices    KernSmooth
# grid         lattice
# gtable       covr, testthat, knitr, rmarkdown, ggplot2, profvis
# highr        knitr, testit
# htmltools    markdown, testthat
# IRdisplay    testthat, withr
# IRkernel     testthat,\nroxygen2
# jsonlite     httr, curl, plyr, testthat, knitr, rmarkdown, R.rsp, sp
# labeling     NA
# magrittr     testthat, knitr
# methods      codetools
# parallel     methods
# pbdZMQ       NA
# pkgconfig    covr, testthat, disposables (>= 1.0.3)
# plogr        Rcpp
# praise       testthat
# prettyunits  codetools, covr, testthat
# R6           knitr, microbenchmark, pryr, testthat, ggplot2, scales
# RColorBrewer NA
# Rcpp         RUnit, inline, rbenchmark, knitr, rmarkdown, pinp, pkgKitten\n(>= 0.1.2)
# rematch      covr, testthat
# repr         methods, highr, Cairo, stringr, testthat, leaflet
# rstudioapi   testthat, knitr, rmarkdown, clipr
# rvest        covr, knitr, png, rmarkdown, spelling, stringi (>= 0.3.1),\ntestthat
# selectr      testthat, XML, xml2
# splines      Matrix, methods
# stats        MASS, Matrix, SuppDists, methods, stats4
# stats4       NA
# tcltk        NA
# tinytex      testit, rstudioapi
# tools        codetools, methods, xml2, curl, commonmark
# utils        methods, xml2, commonmark
# uuid         NA
# viridisLite  hexbin (>= 1.27.0), ggplot2 (>= 1.0.1), testthat, covr
# whisker      markdown
# withr        covr, DBI, knitr, lattice, methods, rmarkdown, RSQLite,\ntestthat (>= 2.1.0)
# xfun         testit, parallel, rstudioapi, tinytex, mime, markdown, knitr,\nhtmltools, base64enc, remotes, rmarkdown
#              Enhances
# assertthat   NA
# base         NA
# base64enc    png
# BH           NA
# bindr        NA
# clipr        NA
# compiler     NA
# crayon       NA
# datasets     NA
# DBI          NA
# desc         NA
# digest       NA
# evaluate     NA
# generics     NA
# graphics     NA
# grDevices    NA
# grid         NA
# gtable       NA
# highr        NA
# htmltools    knitr
# IRdisplay    NA
# IRkernel     NA
# jsonlite     NA
# labeling     NA
# magrittr     NA
# methods      NA
# parallel     snow, nws, Rmpi
# pbdZMQ       NA
# pkgconfig    NA
# plogr        NA
# praise       NA
# prettyunits  NA
# R6           NA
# RColorBrewer NA
# Rcpp         NA
# rematch      NA
# repr         data.table, dplyr, htmlwidgets, vegalite, plotly, geojsonio
# rstudioapi   NA
# rvest        NA
# selectr      NA
# splines      NA
# stats        NA
# stats4       NA
# tcltk        NA
# tinytex      NA
# tools        NA
# utils        NA
# uuid         NA
# viridisLite  NA
# whisker      NA
# withr        NA
# xfun         NA
#              License                        License_is_FOSS
# assertthat   GPL-3                          NA
# base         Part of R 3.6.1                NA
# base64enc    GPL-2 | GPL-3                  NA
# BH           BSL-1.0                        NA
# bindr        MIT + file LICENSE             NA
# clipr        GPL-3                          NA
# compiler     Part of R 3.6.1                NA
# crayon       MIT + file LICENSE             NA
# datasets     Part of R 3.6.1                NA
# DBI          LGPL (>= 2.1)                  NA
# desc         MIT + file LICENSE             NA
# digest       GPL (>= 2)                     NA
# evaluate     MIT + file LICENSE             NA
# generics     GPL-2                          NA
# graphics     Part of R 3.6.1                NA
# grDevices    Part of R 3.6.1                NA
# grid         Part of R 3.6.1                NA
# gtable       GPL-2                          NA
# highr        GPL                            NA
# htmltools    GPL (>= 2)                     NA
# IRdisplay    MIT + file LICENSE             NA
# IRkernel     MIT + file LICENSE             NA
# jsonlite     MIT + file LICENSE             NA
# labeling     MIT + file LICENSE | Unlimited NA
# magrittr     MIT + file LICENSE             NA
# methods      Part of R 3.6.1                NA
# parallel     Part of R 3.6.1                NA
# pbdZMQ       GPL-3                          NA
# pkgconfig    MIT + file LICENSE             NA
# plogr        MIT + file LICENSE             NA
# praise       MIT + file LICENSE             NA
# prettyunits  MIT + file LICENSE             NA
# R6           MIT + file LICENSE             NA
# RColorBrewer Apache License 2.0             NA
# Rcpp         GPL (>= 2)                     NA
# rematch      MIT + file LICENSE             NA
# repr         GPL-3                          NA
# rstudioapi   MIT + file LICENSE             NA
# rvest        GPL-3                          NA
# selectr      BSD_3_clause + file LICENCE    NA
# splines      Part of R 3.6.1                NA
# stats        Part of R 3.6.1                NA
# stats4       Part of R 3.6.1                NA
# tcltk        Part of R 3.6.1                NA
# tinytex      MIT + file LICENSE             NA
# tools        Part of R 3.6.1                NA
# utils        Part of R 3.6.1                NA
# uuid         MIT + file LICENSE             NA
# viridisLite  MIT + file LICENSE             NA
# whisker      GPL-3                          NA
# withr        GPL (>= 2)                     NA
# xfun         MIT + file LICENSE             NA
#              License_restricts_use OS_type MD5sum NeedsCompilation Built
# assertthat   NA                    NA      NA     no               3.6.1
# base         NA                    NA      NA     NA               3.6.1
# base64enc    NA                    NA      NA     yes              3.6.0
# BH           NA                    NA      NA     no               3.6.1
# bindr        NA                    NA      NA     no               3.6.1
# clipr        NA                    NA      NA     no               3.6.1
# compiler     NA                    NA      NA     NA               3.6.1
# crayon       NA                    NA      NA     no               3.6.0
# datasets     NA                    NA      NA     NA               3.6.1
# DBI          NA                    NA      NA     no               3.6.1
# desc         NA                    NA      NA     no               3.6.1
# digest       NA                    NA      NA     yes              3.6.0
# evaluate     NA                    NA      NA     no               3.6.0
# generics     NA                    NA      NA     no               3.6.1
# graphics     NA                    NA      NA     yes              3.6.1
# grDevices    NA                    NA      NA     yes              3.6.1
# grid         NA                    NA      NA     yes              3.6.1
# gtable       NA                    NA      NA     no               3.6.1
# highr        NA                    NA      NA     no               3.6.1
# htmltools    NA                    NA      NA     yes              3.6.0
# IRdisplay    NA                    NA      NA     no               3.6.0
# IRkernel     NA                    NA      NA     NA               3.6.0
# jsonlite     NA                    NA      NA     yes              3.6.0
# labeling     NA                    NA      NA     no               3.6.1
# magrittr     NA                    NA      NA     no               3.6.1
# methods      NA                    NA      NA     yes              3.6.1
# parallel     NA                    NA      NA     yes              3.6.1
# pbdZMQ       NA                    NA      NA     yes              3.6.1
# pkgconfig    NA                    NA      NA     no               3.6.1
# plogr        NA                    NA      NA     no               3.6.1
# praise       NA                    NA      NA     no               3.6.1
# prettyunits  NA                    NA      NA     no               3.6.1
# R6           NA                    NA      NA     no               3.6.1
# RColorBrewer NA                    NA      NA     no               3.6.1
# Rcpp         NA                    NA      NA     yes              3.6.0
# rematch      NA                    NA      NA     no               3.6.1
# repr         NA                    NA      NA     no               3.6.0
# rstudioapi   NA                    NA      NA     no               3.6.1
# rvest        NA                    NA      NA     no               3.6.1
# selectr      NA                    NA      NA     no               3.6.1
# splines      NA                    NA      NA     yes              3.6.1
# stats        NA                    NA      NA     yes              3.6.1
# stats4       NA                    NA      NA     NA               3.6.1
# tcltk        NA                    NA      NA     yes              3.6.1
# tinytex      NA                    NA      NA     no               3.6.1
# tools        NA                    NA      NA     yes              3.6.1
# utils        NA                    NA      NA     yes              3.6.1
# uuid         NA                    NA      NA     yes              3.6.0
# viridisLite  NA                    NA      NA     no               3.6.1
# whisker      NA                    NA      NA     no               3.6.1
# withr        NA                    NA      NA     no               3.6.1
# xfun         NA                    NA      NA     no               3.6.1

# %%
# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------
# How to Install Packages Through Jupyter Notebook
# https://stackoverflow.com/questions/42459423/cannot-install-r-packages-in-jupyter-notebook
# install.packages("tidyverse", repos='http://cran.us.r-project.org')
# install.packages("MASS", repos='http://cran.us.r-project.org')
# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------
library(dplyr)
library(ggplot2)
library(RCurl)
library(tidyverse)
library(MASS)

print(' In case variable x is declared and assigned a value in any other windows then you can use it in other windows too')

#R base contains many default datasets.
#One of the most common datasets in use is the Iris dataset.
#Load it with 
data(iris)

#Let's write it into a file and read it from input. 
#This goes into your working directory.
write.table(iris,file='iris.txt',sep='\t',col.names=T,quote=F,row.names=F)
rm(iris)
#Read in the file we just wrote.
Iris=read.table('iris.txt',header=T,stringsAsFactors=F,sep='\t')
print('Check column names')
colnames(Iris)
head(Iris)
# Out:
# Error in library(dplyr): there is no package called ‘dplyr’
# Traceback:
#
# 1. library(dplyr)
