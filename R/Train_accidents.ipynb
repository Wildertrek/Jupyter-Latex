# %%
# INSTALL PACKAGE ####
install.packages("tidyverse")
# Out:
# also installing the dependencies ‘colorspace’, ‘farver’, ‘labeling’, ‘munsell’, ‘RColorBrewer’, ‘viridisLite’, ‘tinytex’, ‘backports’, ‘generics’, ‘assertthat’, ‘blob’, ‘DBI’, ‘tidyselect’, ‘data.table’, ‘gargle’, ‘ids’, ‘gtable’, ‘isoband’, ‘scales’, ‘cpp11’, ‘BH’, ‘rmarkdown’, ‘selectr’, ‘broom’, ‘dbplyr’, ‘dplyr’, ‘dtplyr’, ‘forcats’, ‘googledrive’, ‘googlesheets4’, ‘ggplot2’, ‘haven’, ‘lubridate’, ‘modelr’, ‘readr’, ‘reprex’, ‘rvest’, ‘tidyr’
# The downloaded binary packages are in
# 	/var/folders/wk/6why77bn1kn0l0pkd4vd3zl00000gn/T//RtmpFvSGBX/downloaded_packages

# %%
# USE PACKAGE ####
library(readxl)

# %%
library(ggplot2)

# %% [markdown]
# Learn about readxl [here](https://www.tidyverse.org/blog/2018/04/readxl-1-1-0/#:~:text=The%20readxl%20package%20makes%20it,xlsx%20format.)

# %%
train_accidents <- read_excel('../data/train_accidents.xls')

# %%
head(train_accidents)
# Out:
#   Acident Railroad Month Day State County    TrkType TrkMnt AccType AccCause
# 1 1       NS       1     1   KY    KENTON    Main    NS     Der     T
# 2 2       ATK      1     2   CA    ALAMEDA   Yard    ATK    Oth     M
# 3 3       BNSF     1     2   MT    DAWSON    Yard    BNSF   Der     H
# 4 4       BNSF     1     2   OK    TULSA     Yard    BNSF   Der     M
# 5 5       MNCW     1     2   CT    FAIRFIELD Main    MNCW   Oth     E
# 6 6       UP       1     2   IL    ST CLAIR  Yard    UP     Der     H
#   EqpDamg TrkDamg Killed Injured RREquip         Speed LocosDer CarsDer
# 1    8485 333700  0      0       FREIGHT TRAIN   24    0        13
# 2 1500000      0  0      0       PASSENGER TRAIN  0    0         0
# 3  103833  17615  0      0       FREIGHT TRAIN   10    0         6
# 4   15000  50000  0      0       LIGHT LOCO(S)    4    5         0
# 5    9964    750  0      0       PASSENGER TRAIN 45    0         0
# 6   10000   3383  0      0       YARD/SWITCHING   2    0         1

# %%
ggplot(data = train_accidents, aes(x=EqpDamg, y=Speed)) + geom_point() +geom_smooth(method=lm) + xlab("Amount of Dollars in Damage") + ylab("Speed(mph)")
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title
