# %%
# INSTALL PACKAGES ####
install.packages("tidyverse")
install.packages("gmodels")

# USE PACKAGES ####
library("tidyverse")
library("gmodels")
# Out:
# The downloaded binary packages are in
# 	/var/folders/wk/6why77bn1kn0l0pkd4vd3zl00000gn/T//Rtmpfl2mTb/downloaded_packages

# %%
# READ IN DATA
loans <- read.csv('../data/loans.csv')

# %%
# VIEW DATA
head(loans)
# Out:
#   X term       loan_status Date      home_ownership
# 1 1  36 months Fully Paid  12/1/2011 RENT
# 2 2  60 months Charged Off 12/1/2011 RENT
# 3 3  36 months Fully Paid  12/1/2011 RENT
# 4 4  36 months Fully Paid  12/1/2011 RENT
# 5 5  60 months Current     12/1/2011 RENT
# 6 6  36 months Fully Paid  12/1/2011 RENT

# %% [markdown]
# ## Part I
# Please answer the following question.
#
# Does the term of the loan influence loan status? If so, how?

# %%
CrossTable(loans$term, loans$loan_status, fisher=FALSE, chisq = TRUE, expected = TRUE, sresid=TRUE, format="SPSS")

# 36 month term loans are more likely to be fully paid off and less likely to be charged off or current.  
# The reverse is true for 60 month loans.
# Out:
#    Cell Contents
# |-------------------------|
# |                   Count |
# |         Expected Values |
# | Chi-square contribution |
# |             Row Percent |
# |          Column Percent |
# |           Total Percent |
# |            Std Residual |
# |-------------------------|
#
# Total Observations in Table:  21957
#
#              | loans$loan_status
#   loans$term | Charged Off  |     Current  |  Fully Paid  |   Row Total |
# -------------|-------------|-------------|-------------|-------------|
#    36 months |       2029  |          0  |      14964  |      16993  |
#              |   2540.011  |    388.509  |  14064.480  |             |
#              |    102.808  |    388.509  |     57.530  |             |
#              |     11.940% |      0.000% |     88.060% |     77.392% |
#              |     61.822% |      0.000% |     82.342% |             |
#              |      9.241% |      0.000% |     68.151% |             |
# ...

# %% [markdown]
# ## Part II
# Please answer the following question.
#
# How has the ability to own a home changed after 2009?

# %% [markdown]
# To reformat the Date column into a new column, use this code:
#
# ```
# loans$DateR <- as.Date(paste(loans$Date), "%m/%d/%Y")
# ```

# %%
loans$DateR <- as.Date(paste(loans$Date), "%m/%d/%Y")

# %%
head(loans)
# Out:
#   X term       loan_status Date      home_ownership DateR
# 1 1  36 months Fully Paid  12/1/2011 RENT           2011-12-01
# 2 2  60 months Charged Off 12/1/2011 RENT           2011-12-01
# 3 3  36 months Fully Paid  12/1/2011 RENT           2011-12-01
# 4 4  36 months Fully Paid  12/1/2011 RENT           2011-12-01
# 5 5  60 months Current     12/1/2011 RENT           2011-12-01
# 6 6  36 months Fully Paid  12/1/2011 RENT           2011-12-01

# %%
loans$Issue_dateR <- as.Date(loans$DateR, format="%b-%d")

# %%
loans1 <- separate(loans, Issue_dateR, c("Ignore", "Issue_Month", "Issue_Year"), sep="-")

# %%
loans1$Issue_MonthR <- NA
loans1$Issue_MonthR[loans1$Issue_Year == "07"] <- 0
loans1$Issue_MonthR[loans1$Issue_Year == "11"] <- 1

# %%
loans1$RentvOwn <- NA
loans1$RentvOwn[loans1$home_ownership == "RENT"] <- 0
loans1$RentvOwn[loans1$home_ownership == "OWN"] <- 1

# %%
loans1
# Out:
#       X     term       loan_status Date      home_ownership DateR      Ignore
# 1      1     36 months Fully Paid  12/1/2011 RENT           2011-12-01 2011
# 2      2     60 months Charged Off 12/1/2011 RENT           2011-12-01 2011
# 3      3     36 months Fully Paid  12/1/2011 RENT           2011-12-01 2011
# 4      4     36 months Fully Paid  12/1/2011 RENT           2011-12-01 2011
# 5      5     60 months Current     12/1/2011 RENT           2011-12-01 2011
# 6      6     36 months Fully Paid  12/1/2011 RENT           2011-12-01 2011
# 7      7     60 months Fully Paid  12/1/2011 RENT           2011-12-01 2011
# 8      8     36 months Fully Paid  12/1/2011 RENT           2011-12-01 2011
# 9      9     60 months Charged Off 12/1/2011 OWN            2011-12-01 2011
# 10    10     60 months Charged Off 12/1/2011 RENT           2011-12-01 2011
# 11    11     60 months Fully Paid  12/1/2011 OWN            2011-12-01 2011
# ...

# %%
CrossTable(loans1$RentvOwn, loans1$Issue_MonthR, fisher=TRUE, chisq = TRUE, mcnemar = TRUE, expected = TRUE, sresid=TRUE, format="SPSS")

# Although the overall test is significant, when standardized residuals are examined, 
# it looks like the number of people renting to owning houses is similar from 2007 to 2011.
# Out:
# Warning message in chisq.test(t, correct = FALSE, ...):
# “Chi-squared approximation may be incorrect”
#    Cell Contents
# |-------------------------|
# |                   Count |
# |         Expected Values |
# | Chi-square contribution |
# |             Row Percent |
# |          Column Percent |
# |           Total Percent |
# |            Std Residual |
# |-------------------------|
#
# Total Observations in Table:  21957
#
#                 | loans1$DateR
# ...

# %% [markdown]
# ## Part III
# Please answer the following question.
#
# The news just ran a story that in America, only 15% of homes are fully paid, 10% have given up on paying it back ("charged off"), and 75% are current in the loan. Does it seem likely that the data for this hands-on came from the larger population of America?
