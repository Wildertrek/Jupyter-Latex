# %%
# INSTALL PACKAGES ####
install.packages("gmodels")
install.packages("tidyr")
install.packages("dplyr")
# Out:
# The downloaded binary packages are in
# 	/var/folders/wk/6why77bn1kn0l0pkd4vd3zl00000gn/T//Rtmpm6mqLc/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/wk/6why77bn1kn0l0pkd4vd3zl00000gn/T//Rtmpm6mqLc/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/wk/6why77bn1kn0l0pkd4vd3zl00000gn/T//Rtmpm6mqLc/downloaded_packages

# %% [markdown]
# # USE PACKAGES ####
# library("gmodels")
# library("tidyr")
# library("dplyr")

# %%
# READ IN DATA
loans <- read.csv('../data/loans.csv')

# %%
loans_dictionary <- read.csv('../data/loans_dictionary.csv')

# %%
# VIEW DATA
head(loans)
# Out:
#   X term       loan_status Date      home_ownership
# 1 1  36 months Fully Paid  12/1/2011 RENT
# 2 2  60 months Charged Off 12/1/2011 RENT
# 3 3  36 months Fully Paid  12/1/2011 RENT
# 4 4  36 months Fully Paid  12/1/2011 RENT
# 5 5  60 months Current     12/1/2011 RENT
# 6 6  36 months Fully Paid  12/1/2011 RENT

# %% [markdown]
# ## Part I
# Please answer the following question.
#
# Does the term of the loan influence loan status? If so, how?

# %%
#make a table
CrossTable(loans$term, loans$loan_status, chisq = TRUE, expected = TRUE, sresid=TRUE, format="SPSS")
# Out:
#    Cell Contents
# |-------------------------|
# |                   Count |
# |         Expected Values |
# | Chi-square contribution |
# |             Row Percent |
# |          Column Percent |
# |           Total Percent |
# |            Std Residual |
# |-------------------------|
#
# Total Observations in Table:  21957
#
#              | loans$loan_status
#   loans$term | Charged Off  |     Current  |  Fully Paid  |   Row Total |
# -------------|-------------|-------------|-------------|-------------|
#    36 months |       2029  |          0  |      14964  |      16993  |
#              |   2540.011  |    388.509  |  14064.480  |             |
#              |    102.808  |    388.509  |     57.530  |             |
#              |     11.940% |      0.000% |     88.060% |     77.392% |
#              |     61.822% |      0.000% |     82.342% |             |
#              |      9.241% |      0.000% |     68.151% |             |
# ...

# %% [markdown]
# # p is significant, which means there is an influence, all the residuals are well above or below 2.
# # it looks as if shorter terms are current or charged off way less than expected, and longer terms are fully paid less (often?) than expected

# %%
loans_dictionary
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# “input string 2 is invalid in this locale”
# Warning message in FUN(X[[i]], ...):
# ...
