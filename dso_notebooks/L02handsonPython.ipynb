# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("Seattle_ParksnRec.csv")

# %%
df.head()
# Out:
#   Geographic Region  Year  # of trips Winter  # of participants Winter  \
# 0           Central  2005                 13                       154
# 1           Central  2006                 17                       229
# 2           Central  2007                 17                       222
# 3           Central  2008                 18                       300
# 4           Central  2009                 18                       276
#
#    # of trips Spring  # of participants Spring  # of trips Summer  \
# 0                 18                       290                 20
# 1                 16                       227                 19
# 2                 15                       244                 13
# 3                 19                       335                 20
# 4                 23                       302                 25
#
#    # of participants Summer  # of trips Fall  # of participants Fall  \
# ...

# %% [markdown]
# # of trips Winter

# %%
sns.distplot(df[["# of trips Winter"]]**(1/2),bins=8)

# %%
sns.distplot(df[["# of trips Winter"]], bins=8)

# %% [markdown]
# # of participants Winter

# %%
sns.distplot(df[["# of participants Winter"]])

# %%
sns.distplot(df[["# of participants Winter"]]**(1/2))

# %% [markdown]
# # of trips Spring

# %%
sns.distplot(df[["# of trips Spring"]])

# %%
sns.distplot(df[["# of trips Spring"]]**(1/2))

# %% [markdown]
# # of participants Spring
# - of trips Summer
# - of participants Summerm

# %%
sns.distplot(df[["# of participants Spring"]])

# %%
sns.distplot(df[["# of participants Spring"]]**(1/2))

# %% [markdown]
# # of trips Summer

# %%
sns.distplot(df[["# of trips Summer"]])

# %% [markdown]
# # - of participants Summer

# %%
sns.distplot(df[["# of participants Summer"]])
