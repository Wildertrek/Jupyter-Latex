# %%
import pandas as pd

# %%
anime = pd.read_csv('C:/Users/meredith.dodd/Desktop/lms-student-resources/src/documents/V2/DataScience/Big-Data/anime/anime.csv')
anime.head()
# Out:
#    anime_id                              name  \
# 0     32281                    Kimi no Na wa.
# 1      5114  Fullmetal Alchemist: Brotherhood
# 2     28977                          Gintama°
# 3      9253                       Steins;Gate
# 4      9969                     Gintama&#039;
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
#
#    members
# 0   200630
# 1   793665
# 2   114262
# 3   673572
# 4   151266

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12294 entries, 0 to 12293
# Data columns (total 7 columns):
# anime_id    12294 non-null int64
# name        12294 non-null object
# genre       12232 non-null object
# type        12269 non-null object
# episodes    12294 non-null object
# rating      12064 non-null float64
# members     12294 non-null int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 672.4+ KB

# %%
anime.dropna(inplace = True)

# %%
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12017 entries, 0 to 12293
# Data columns (total 7 columns):
# anime_id    12017 non-null int64
# name        12017 non-null object
# genre       12017 non-null object
# type        12017 non-null object
# episodes    12017 non-null object
# rating      12017 non-null float64
# members     12017 non-null int64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 751.1+ KB

# %%
anime.to_csv(r'C:/Users/meredith.dodd/Desktop/lms-student-resources/src/documents/V2/DataScience/Big-Data/AnimeClean.csv')

# %%
boardgames = pd.read_csv('C:/Users/meredith.dodd/Documents/Learning Big Data/boardgames1.csv')
boardgames.head()
# Out:
#          id  yearpublished  minplayers  maxplayers  playingtime  minplaytime  \
# 0   12333.0         2005.0         2.0         2.0        180.0        180.0
# 1  120677.0         2012.0         2.0         5.0        150.0         60.0
# 2  102794.0         2013.0         1.0         7.0        210.0         30.0
# 3   25613.0         2006.0         2.0         4.0        240.0        240.0
# 4    3076.0         2002.0         2.0         5.0        150.0         90.0
#
#    maxplaytime  minage  users_rated  average_rating  bayes_average_rating  \
# 0        180.0    13.0      20113.0             8.0                  8.22
# 1        150.0    12.0      14383.0             8.0                  8.14
# 2        210.0    12.0       9262.0             8.0                  8.07
# 3        240.0    12.0      13294.0             8.0                  8.06
# 4        150.0    12.0      39883.0             8.0                  8.05
#
# ...

# %%
boardgames.dropna(inplace = True)

# %%
boardgames.to_csv(r'C:\Users\meredith.dodd\Documents\Learning Big Data\boardgames3.csv')

# %%
asteroids = pd.read_csv('C:/Users/meredith.dodd/Desktop/lms-student-resources/src/documents/V2/DataScience/Big-Data/Asteroid2.csv')
asteroids.head()
# Out:
# C:\Users\meredith.dodd\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           a         e          i          om           w         q        ad  \
# 0  2.769165  0.076009  10.594067   80.305532   73.597694  2.558684  2.979647
# 1  2.772466  0.230337  34.836234  173.080063  310.048857  2.133865  3.411067
# 2  2.669150  0.256942  12.988919  169.852760  248.138626  1.983332  3.354967
# 3  2.361418  0.088721   7.141771  103.810804  150.728541  2.151909  2.570926
# 4  2.574249  0.191095   5.366988  141.576604  358.687608  2.082324  3.066174
#
#       per_y  data_arc condition_code  n_obs_used     H  diameter  albedo  \
# 0  4.608202    8822.0              0      1002.0  3.34   939.400  0.0900
# 1  4.616444   72318.0              0      8490.0  4.13   545.000  0.1010
# ...

# %%
asteroids.dropna(inplace = True)

# %%
asteroids.to_csv(r'C:\Users\meredith.dodd\Documents\Learning Big Data\asteroids4.csv')
